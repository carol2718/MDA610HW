# %% [markdown]
# # Loan Data Analysis

# %% [markdown]
# - A loan status data set will be loaded and analyzed.
# - Data Dictionary
#     - ID: loan ID
#     - Gender: gender of the debtor
#     - Dependent: the number of people who claim the debtor as dependent
#     - Education: the debtor has a college degree or not
#     - Income: the debtor's monthly family income
#     - Amount: the balance of the loan in thousand dollars
#     - Credit: 1 - good credit history; 0 - bad credit history
#     - Area: the debtor is from an urban area, a rural area or a semiurban area
#     - Status: Y - the debtor is repaying the loan; N - the debtor is not repaying the loan
# - Follow the *TODO* instruction to answer each question with a Python code snippet. After you finish answering all the questions, save the notebook with the necessary output for each code cell and then upload the notebook to Blackboard.

# %%
# initialization and data loading
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
data = pd.read_csv('https://raw.githubusercontent.com/postmda/MDA610/master/Pages/LoanData.csv')

# %% [markdown]
# **TODO 1**
# `data` is the DataFrame that contains the loan status data. Find the number of columns in the DataFrame.

# %%
#####TODO 1#####
pass
data.shape[1]
# Out:
# 9

# %% [markdown]
# **TODO 2**
# Find the number of columns with missing values in the DataFrame.

# %%
#####TODO 2#####
pass
np.sum(data.isnull(), axis = 0)
# Out:
# ID             0
# Gender        13
# Dependents    15
# Education      0
# Income         0
# Amount         0
# Credit        50
# Area           0
# Status         0
# dtype: int64

# %% [markdown]
# **TODO 3**
# Show the last six rows of the DataFrame.

# %%
#####TODO 3#####
pass
data.loc[:].tail(6)
# Out:
#            ID  Gender Dependents Education  Income  Amount  Credit       Area  \
# 608  LP002974    Male          0  Graduate  5182.0     108     1.0      Rural
# 609  LP002978  Female          0  Graduate  2900.0      71     1.0      Rural
# 610  LP002979    Male         3+  Graduate  4106.0      40     1.0      Rural
# 611  LP002983    Male          1  Graduate  8312.0     253     1.0      Urban
# 612  LP002984    Male          2  Graduate  7583.0     187     1.0      Urban
# 613  LP002990  Female          0  Graduate  4583.0     133     0.0  Semiurban
#
#     Status
# 608      Y
# 609      Y
# 610      Y
# 611      Y
# 612      Y
# 613      N

# %% [markdown]
# **TODO 4**
# Show columns `ID` and `Income` of the first, second and fourth rows in the DataFrame.

# %%
#####TODO 4#####
pass

data.iloc[0:2].loc[:,['ID', 'Income']]
# Out:
#          ID  Income
# 0  LP001002  5849.0
# 1  LP001003  6091.0

# %% [markdown]
# **TODO 5**
# Find the highest loan balance in thousand dollars.

# %%
#####TODO 5#####
pass
np.sort(data[:,3])[-5]

data['Amount'].argmax()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-752a062c8d48> in <module>
#       1 #####TODO 5#####
#       2 pass
# ----> 3 np.sort(data[:,3])[-5]
#       4
#       5 data['Amount'].argmax()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#    2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 3)' is an invalid key

# %% [markdown]
# **TODO 6**
# Find the number of debtors who are repaying their loans.

# %%
#####TODO 6#####
pass

np.sum(data.loc[ : , 'Status' ] != 'N')
# Out:
# 614

# %% [markdown]
# **TODO 7**
# Find the number of debtors who has a college degree and a loan balance above 300 thousand dollars.

# %%
#####TODO 7#####
pass
data[data.Amount> 300]
# Out:
#            ID  Gender Dependents Education   Income  Amount  Credit  \
# 9    LP001020    Male          1  Graduate  23809.0     349     1.0
# 21   LP001046    Male          1  Graduate  11580.0     315     1.0
# 34   LP001100    Male         3+  Graduate  15500.0     320     1.0
# 67   LP001233    Male          1  Graduate  10750.0     312     1.0
# 126  LP001448     NaN         3+  Graduate  23803.0     370     1.0
# 130  LP001469    Male          0  Graduate  20166.0     650     NaN
# 155  LP001536    Male         3+  Graduate  39999.0     600     0.0
# 171  LP001585     NaN         3+  Graduate  51763.0     700     1.0
# 177  LP001610    Male         3+  Graduate  16816.0     495     0.0
# 258  LP001859    Male          0  Graduate  16783.0     304     1.0
# 260  LP001865    Male          1  Graduate  10333.0     330     NaN
# 278  LP001907    Male          0  Graduate  14583.0     436     1.0
# 308  LP001996    Male          0  Graduate  20233.0     480     1.0
# 325  LP002067    Male          1  Graduate  13649.0     376     0.0
# 333  LP002101    Male          0  Graduate  63337.0     490     1.0
# 351  LP002140    Male          0  Graduate  12917.0     308     1.0
# 369  LP002191    Male          0  Graduate  24996.0     570     1.0
# 372  LP002201    Male          2  Graduate  17196.0     380     1.0
# 409  LP002317    Male         3+  Graduate  81000.0     360     0.0
# 432  LP002386    Male          0  Graduate  12876.0     405     1.0
# 487  LP002547    Male          1  Graduate  18333.0     500     1.0
# 506  LP002624    Male          0  Graduate  27500.0     480     NaN
# 514  LP002652    Male          0  Graduate   9481.0     311     1.0
# 523  LP002693    Male          2  Graduate  15114.0     480     1.0
# 524  LP002697    Male          0  Graduate   6767.0     345     1.0
# 525  LP002699    Male          2  Graduate  17500.0     400     1.0
# 536  LP002734    Male          0  Graduate  10039.0     324     1.0
# 561  LP002813  Female          1  Graduate  19484.0     600     1.0
# 600  LP002949  Female         3+  Graduate  42083.0     350     NaN
# 604  LP002959  Female          1  Graduate  12000.0     496     1.0
#
#           Area Status
# 9    Semiurban      N
# 21       Urban      Y
# 34       Rural      N
# 67       Urban      Y
# 126      Rural      Y
# 130      Urban      Y
# 155  Semiurban      Y
# 171      Urban      Y
# 177  Semiurban      N
# 258      Rural      N
# 260      Urban      Y
# 278  Semiurban      Y
# 308      Rural      N
# 325      Rural      N
# 333      Urban      Y
# 351      Rural      N
# 369      Rural      N
# 372      Rural      Y
# 409      Rural      N
# 432  Semiurban      Y
# 487      Urban      N
# 506      Urban      Y
# 514      Rural      N
# 523      Rural      Y
# 524  Semiurban      N
# 525      Rural      Y
# 536      Urban      Y
# 561  Semiurban      Y
# 600      Urban      N
# 604  Semiurban      Y

# %% [markdown]
# **TODO 8** Compute the mean monthly family income of the debtors from an urban area.

# %%
#####TODO 8#####
pass
np.sum(data.loc[ : , 'Area' ] = 'Urban')
np.mean(data[: (data.loc[ : , 'Area' ] = 'Urban')], axis = 1, )
# Out:
#   File "<ipython-input-63-59509ced82d8>", line 4
#     np.mean(data[: (data.loc[ : , 'Area' ] = 'Urban')], axis = 1, )
#                                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# **TODO 9**
# Sort the DataFrame in ascending order of column `Income`. Show the first three rows in the sorted DataFrame.

# %%
#####TODO 9#####
pass

# %% [markdown]
# **TODO 10**
# Return the index of the row with the highest income.

# %%
#####TODO 10#####
pass
np.argmax(data[ :,5 ])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-80d93f7986bd> in <module>
#       1 #####TODO 10#####
#       2 pass
# ----> 3 np.argmax(data[ :,5 ])
#       4
#       5
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#    2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 5)' is an invalid key
